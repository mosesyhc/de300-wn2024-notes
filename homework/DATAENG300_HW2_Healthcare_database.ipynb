# %% [markdown]
# # Homework 2: Two ways with MIMIC-III

# %% [markdown]
# In this homework, we will explore the MIMIC-III patient database again with both a relational and a non-relational database perspective.
#
# **Some useful resources:**
# - Entity-relationship diagram generated by SchemaSpy (https://mit-lcp.github.io/mimic-schema-spy/relationships.html).
#   - If you click on each table, it provides the view for only the related tables.
#   - The description for each column is also available.  For full details, refer to the official MIMIC-III documentation (https://mimic.mit.edu/docs/iii/).

# %% [markdown]
# **General rules of thumb for homeworks:**
# - Read the homework questions carefully.
# - Explain your choices.
# - Present your findings concisely.
# - Use tables, plots, and summary statistics to aid your presentation of findings.
# - If you have an idea in mind but could not implement (in code), present the idea thoroughly and how you would have implemented the code.

# %% [markdown]
# ## Dataset
# We will use six of the tables (one additional table to Lab 3) provided in the MIMIC-III database:
#
# - ADMISSIONS.csv
# - ICUSTAYS.csv
# - PATIENTS.csv
# - PROCEDURES_ICD.csv
# - D_ICD_PROCEDURES.csv
# - PRESCRIPTIONS.csv (*new*)
#
# The `.csv` files can be found under https://github.com/mosesyhc/de300-wn2024-notes/tree/main/lab/dataset/mimic3.
#
# *Note*: you may find creating new columns necessarily. By all means, do it to facilitate your analyses.

# %% [markdown]
# ### Part I (Relational)
# 1. Load all the data into a `duckdb` database.  Refer to [Lab 3](https://github.com/mosesyhc/de300-wn2024-notes/blob/main/lab/DATAENG300_Lab3_Template.ipynb) for guidance to create your own database.
# 2. Answer the following *analysis questions* along with your queries:
#    1. Create a summary of type of drugs and their total amount used by ethnicity.  Report the top usage in each ethnicity group.
#    2. Create a summary of procedures performed on patients by age groups (<=19, 20-49, 50-79, >80).  Report the top procedure performed in each age group.
#    3. How long do patients stay in the ICU? Is there a difference in the ICU length of stay among gender?

# %% [markdown]
# ## Part II (Non-relational)
# 1. Verify access to Keyspaces via your Jupyter notebook on EC2.  Follow the instructions [here](https://mosesyhc.github.io/de300-wn2024-notes/notes/0b-access-keyspaces.html).
#    - The instructions imply that you do not need to run your analysis using Jupyter notebook on EC2.  However, I would strongly recommend doing so.
# 2. Please sign and acknowledge the following statement:
#    > *No copies of the AWS crendentials file is stored on any publicly accessible location, nor is the file in any way shared with anyone outside of DATA_ENG 300 (Winter 2024).*
# 3. For each of the *analysis questions* above, do the following:
#    1. Design a Cassandra table for the specific analysis.  Report your table creation query.
#    2. Upload the data into the table to facilitate answering the question.  Report your code for uploading the data.
#    3. Report the query (without aggregation) for extracting relevant data to answer the question.
#    4. (*optional*) For your sanity check, verify that the extraction produces the desired data.

# %% [markdown]
# # Generative AI disclosure
# In this course, you are generally allowed to use Generative Artificial Intelligence (GAI). Any use of GAI should be accompanied by a disclosure at the end of an assignment explaining (1) what you used GAI for; (2) the specific tool(s) you used; and (3) what prompts you used to get the results.
#
# **Include** any disclosure below.
